# %% [markdown]
# ### wiset 여대학원생 공학연구팀제 파이썬 기초 문제

# %% [markdown]
# - 2021.05.23,5월 두번째 회의 시간에 배운 내용을 토대로 아래의 문제들을 풀어주세요.
# - 모르는 문제는 구글 검색창을 이용하세요.
# - 기한은 5월 31일까지입니다.
# - 기한을 엄수하셔서 잔디 숙제란에 올려주시기 바랍니다.
# - 저장 방법은 5월_이름.ipynb입니다.

# %% [markdown]
# 1.화면에 Hello World 문자열을 출력하세요.

# %% [markdown]
# 2. 화면에 문자열을 출력하세요.(문자열 : 여대학원생 공학연구팀제)

# %% [markdown]
# 3. a,b,c에 각각 10,20,30 숫자를 저장하고 a와 b와 c의 합을 구하세요.

# %% [markdown]
# 4. print() 함수를 사용하여 다음과 같이 출력하세요. <hint : sep를 이용하세요.>
#
# 실행 예 : 월요일, 화요일, 수요일, 목요일

# %% [markdown]
# 5. 잔디에서 csv 파일 하나를 다운받으세요(csv파일명:wiset)
#
# wiset이라는 이름으로 csv 파일을 읽어오세요.

# %% [markdown]
# 다음과 같이 읽어오시면 됩니다.
# ![image.png](attachment:image.png)

# %% [markdown]
# 6. wiset의 앞부분만 출력하세요.

# %% [markdown]
# 7. wiset의 뒷부분만 출력하세요.

# %% [markdown]
# 8. wiset의 a 열을 출력하세요.

# %% [markdown]
# 9. 다음과 같이 데이터프레임을 하나 만들어 Num이라는 변수에 저장하시오.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 10. Num의 apple열과 banana열을 동시에 출력하세요
